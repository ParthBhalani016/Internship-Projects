# %% [markdown]
# **Name-Parth Bhalani**
# * Dataset: INX Future Inc – Employee Performance Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# !pip install xlrd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_excel("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls", engine="xlrd")

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %% [markdown]
# ### Domain Analysis

# %% [markdown]
# 1️⃣ EmpNumber
# * Unique ID for each employee,No impact on performance
# * Used only for identification
#
# 2️⃣ Age
# * Age of the employee
# * Helps analyze performance trends across age groups
#
# 3️⃣ Gender
# * Male / Female
# * Used to check if performance varies by gender (bias check)
#
# 4️⃣ Education
# * Education level (e.g., Graduation, Master’s)
# * Higher education may relate to better skill level
#
# 5️⃣ EducationField
# * Field of education (Life Sciences, Technical, HR, etc.)
# * Used to see which background performs better
#
# 6️⃣ Department
# * Department employee works in (Sales, HR, R&D, etc.)
# * Very important for department-wise performance analysis
#
# 7️⃣ JobRole
# * Employee’s role (Manager, Developer, Analyst, etc.)
# * Different roles have different performance expectations
#
# 8️⃣ BusinessTravel
# * Frequency of work travel
# * Frequent travel may affect work-life balance and performance
#
# 9️⃣ DistanceFromHome
# * Distance between home and office
# * Long distance can reduce productivity and satisfaction
#
# 🔟 EnvironmentSatisfaction
# * How satisfied employee is with work environment (1–4 scale)
# * One of the most important performance factors
#
# 1️⃣1️⃣ JobSatisfaction
# * Satisfaction with job role and responsibilities
# * High satisfaction usually → high performance
#
# 1️⃣2️⃣ WorkLifeBalance
# * Balance between work and personal life
# * Poor balance often leads to burnout
#
# 1️⃣3️⃣ HourlyRate / MonthlyIncome
# * Compensation related columns
# * Used to see if pay impacts performance
#
# 1️⃣4️⃣ PercentSalaryHike
# * Salary increment percentage
# * Shows reward for past performance
#
# 1️⃣5️⃣ YearsAtCompany
# * Total years employee worked in company
# * Experience often improves performance
#
# 1️⃣6️⃣ YearsInCurrentRole
# * Time spent in current role
# * Stability in role can improve efficiency
#
# 1️⃣7️⃣ YearsSinceLastPromotion
# * Time since last promotion
# * Long gaps may reduce motivation
#
# 1️⃣8️⃣ YearsWithCurrManager
# * Time working with current manager
# * Good manager-employee relation boosts performance
#
# 1️⃣9️⃣ OverTime
# * Whether employee works overtime
# * Excess overtime may cause fatigue
#
# 2️⃣0️⃣ TrainingTimesLastYear
# * Number of trainings attended
# * More training = better skills
#
# 2️⃣1️⃣ Attrition
# * Whether employee left the company or not
# * Not directly used for performance prediction
#
# 2️⃣2️⃣ PerformanceRating
# * Employee performance score (Low / Good / Excellent)
# * THIS IS THE TARGET VARIABLE

# %% [markdown]
# **Business Problem Understanding**
# * Problem Faced by INX Future Inc:
#     * Declining employee performance index
#     * Increase in service delivery escalations
#     * Client satisfaction dropped by 8%
#     * Management wants data-driven insights, not emotional decisions
#
# **Business Constraint**
# * Avoid harming employee morale
# * Maintain reputation as a “best employer”
# * Hence, penalizing employees blindly is risky.

# %% [markdown]
# #### Objective of the Project
# * The main objectives are:
# 1. Analyze department-wise employee performance
# 2. Identify key factors influencing performance
# 3. Build a predictive ML model for employee performance
# 4. Provide actionable recommendations to management

# %% [markdown]
# #### Input & Output of the System
# 🔹 Input
# * Employee-related attributes:
# * Age, Gender, Education
# * Job Role, Department
# * Satisfaction scores
# * Experience & tenure
# * Training & compensation
#
# 🔹 Output
# * Employee Performance Rating (Target)
# * Performance prediction for new employees

# %% [markdown]
# **This number indicate below features in columns**
#
# EmpEducationLevel
# 1. 'Below College'
# 2. 'College'
# 3. 'Bachelor'
# 4. 'Master'
# 5. 'Doctor'
#
# EmpEnvironmentSatisfaction
# 1. 'Low'
# 2. 'Medium'
# 3. 'High'
# 4. 'Very High'
#
# EmpJobInvolvement
# 1. 'Low'
# 2. 'Medium'
# 3. 'High'
# 4. 'Very High'
#
# EmpJobSatisfaction
# 1. 'Low'
# 2. 'Medium'
# 3. 'High'
# 4. 'Very High'
#
# PerformanceRating
# 1. 'Low'
# 2. 'Good'
# 3. 'Excellent'
# 4. 'Outstanding'
#
# RelationshipSatisfaction
# 1. 'Low'
# 2. 'Medium'
# 3. 'High'
# 4. 'Very High'
#
# EmpWorkLifeBalance
# 1. 'Bad'
# 2. 'Good'
# 3. 'Better'
# 4. 'Best'

# %% [markdown]
# #### Categorical Features
# * EmpNumber → Employee ID (identifier)
# * Gender → Male / Female
# * EducationField → Field of study
# * Department → HR / Sales / R&D
# * EmpJobRole → Role of employee
# * BusinessTravel → Travel frequency
# * OverTime → Yes / No
# * Attrition → Yes / No
# * EnvironmentSatisfaction
# * JobSatisfaction
# * WorkLifeBalance
# * 🎯 Target (Categorical)
# * PerformanceRating → Employee performance level

# %% [markdown]
# #### Numerical Features
# * Age
# * DistanceFromHome
# * HourlyRate
# * MonthlyIncome
# * PercentSalaryHike
# * TrainingTimesLastYear
# * YearsAtCompany
# * YearsInCurrentRole
# * YearsSinceLastPromotion
# * YearsWithCurrManager

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# * In this dataset, there is absent any null value.

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
df.groupby('EmpDepartment')['PerformanceRating'].value_counts()
# Out:
# EmpDepartment           PerformanceRating
# Data Science            3                     17
#                         4                      2
#                         2                      1
# Development             3                    304
#                         4                     44
#                         2                     13
# Finance                 3                     30
#                         2                     15
#                         4                      4
# Human Resources         3                     38
#                         2                     10
#                         4                      6
# Research & Development  3                    234
#                         2                     68
#                         4                     41
# Sales                   3                    251
#                         2                     87
#                         4                     35
# Name: count, dtype: int64

# %% [markdown]
# #### Business Insight
# * Identifies high-performing and low-performing departments
# * Helps management focus on weak departments

# %% [markdown]
# ### EDA

# %%
# Select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Set figure size
plt.figure(figsize=(15, 20))

# Plot histograms
for i, col in enumerate(num_cols, 1):
    plt.subplot(len(num_cols)//3 + 1, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# * we can see that most columns have skewed data.

# %%
cat_cols = ['Gender','EmpDepartment','EmpEducationLevel','MaritalStatus','OverTime','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpRelationshipSatisfaction',
            'EmpJobSatisfaction','EmpWorkLifeBalance','Attrition','PerformanceRating']

for col in df[cat_cols].columns:
    if col != 'PerformanceRating':  # skip the target column
        plt.figure(figsize=(12, 3))
        
        # Count Plot (Histogram for categorical or discrete numerical features)
        plt.subplot(1, 2, 1)
        sns.countplot(x=col, data=df, hue='PerformanceRating')
        plt.title(f"Count Plot of {col}")
        plt.xlabel(col)
        plt.ylabel("Count")

# %% [markdown]
# * This show how our data is imbalanced.
# * One gender has a higher employee count compared to the other
# * Certain departments have significantly more employees.Some departments are smaller in size.
# * Most employees fall into mid to high education levels.Very few employees belong to extreme education categories.
# * Most employees report medium to high satisfaction,Fewer employees are extremely dissatisfied.
# * Positive workplace relationships are dominant, supporting collaborative performance.
# * Higher job satisfaction is common, which positively influences employee performance.
# * Most employees report acceptable to good work-life balance,Very few report poor balance.
# * Workforce is well-distributed and mostly satisfied
# * Low-satisfaction categories are minor but critical
# * Satisfaction & involvement variables are strong predictors of performance
# * No extreme imbalance, making dataset suitable for ML

# %% [markdown]
# ### Feature Engineering

# %%
# Identifier columns were removed as they do not contribute to prediction.
df.drop(columns=['EmpNumber'], inplace=True, errors='ignore')

# %%
# Let's check outliers.
num_cols = ['Age','DistanceFromHome','EmpHourlyRate','NumCompaniesWorked','EmpLastSalaryHikePercent','TotalWorkExperienceInYears','TrainingTimesLastYear',
    'ExperienceYearsAtThisCompany','ExperienceYearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'
]

# Grid setup
cols = 3
rows = math.ceil(len(num_cols) / cols)

plt.figure(figsize=(18, 5 * rows))

for i, col in enumerate(num_cols, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# * The detected outliers mainly occur in income and experience-related variables, which represent senior employees and valid business scenarios. Since these are not data errors, no outlier removal was performed. Instead, appropriate scaling techniques were applied.

# %%
# Now aplly one hot encoding to categorical columns.
encode_cols = ['Gender','EducationBackground','MaritalStatus','EmpDepartment','EmpJobRole','BusinessTravelFrequency',
               'OverTime','Attrition']
df = pd.get_dummies(
    df,
    columns=encode_cols,
    drop_first=True
)

# %%
# Compute correlation matrix
corr_matrix = df.corr()

# Plot heatmap
plt.figure(figsize=(40,40))
sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    annot=True,
    linewidths=0.5
)

plt.title('Correlation Heatmap of Features')
plt.show()

# %%
# Compute correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper_triangle = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

# Find columns with correlation greater than 0.9
high_corr_cols = [
    column for column in upper_triangle.columns
    if any(upper_triangle[column] > 0.9)
]

high_corr_cols
# Out:
# ['EmpJobRole_Finance Manager', 'EmpJobRole_Human Resources']

# %% [markdown]
# * We can see that there are two columns which have more than >0.9 corrilation. so drop them.

# %%
df.drop(columns=high_corr_cols, inplace=True)

# %%
# Let's check our data is balanced or imbalanced.
df['PerformanceRating'].value_counts()
# Out:
# PerformanceRating
# 3    874
# 2    194
# 4    132
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='PerformanceRating')
plt.title('Class Distribution of PerformanceRating')
plt.show()

# %% [markdown]
# this is highly imbalance data so we use smote in model selection.

# %% [markdown]
# ### Model Selection

# %%
from sklearn.model_selection import train_test_split
X = df.drop("PerformanceRating",axis=1)
Y = df['PerformanceRating']
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y_encoded = le.fit_transform(Y)

# %%
from imblearn.over_sampling import SMOTE
x_train, x_test, y_train, y_test = train_test_split(
    X, Y_encoded, test_size=0.2, random_state=0, stratify=Y_encoded
)

sm = SMOTE(random_state=0)
x_train_smote, y_train_smote = sm.fit_resample(x_train, y_train)

# %% [markdown]
# ### Model Creation

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# %%
models = {
    "Logistic Regression": Pipeline([
        ("scaler", StandardScaler()),
        ("model", LogisticRegression(max_iter=1000))
    ]),

    "SVM": Pipeline([
        ("scaler", StandardScaler()),
        ("model", SVC(kernel='rbf'))
    ]),

    "Decision Tree": DecisionTreeClassifier(random_state=0),

    "Bagging": BaggingClassifier(
        n_estimators=100,
        random_state=0
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        random_state=0
    ),

    "XGBoost": XGBClassifier(
        eval_metric='mlogloss',
        use_label_encoder=False,
        random_state=0
    ),

    "ANN": Pipeline([
        ("scaler", StandardScaler()),
        ("model", MLPClassifier(
            hidden_layer_sizes=(64, 32),
            max_iter=500,
            random_state=0
        ))
    ])
}

# %%
results = {}

for name, model in models.items():
    # Train on SMOTE data
    model.fit(x_train_smote, y_train_smote)
    
    # Predict on test data
    y_pred = model.predict(x_test)
    
    # Metrics
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    results[name] = {
        "Accuracy": acc,
        "F1 Score": f1
    }
    
    print(f"\n{name}")
    print("Accuracy:", acc)
    print("F1 Score:", f1)
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.7958333333333333
# F1 Score: 0.7967990911343131
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.56      0.59        39
#            1       0.87      0.86      0.86       175
#            2       0.58      0.73      0.64        26
#
#     accuracy                           0.80       240
#    macro avg       0.69      0.72      0.70       240
# weighted avg       0.80      0.80      0.80       240
#
#
# SVM
# Accuracy: 0.7666666666666667
# F1 Score: 0.7270846360499318
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.23      0.33        39
#            1       0.78      0.95      0.86       175
#            2       0.73      0.31      0.43        26
#
#     accuracy                           0.77       240
#    macro avg       0.70      0.50      0.54       240
# weighted avg       0.75      0.77      0.73       240
# ...

# %% [markdown]
# ### Final Project Report & Conclusion
#
# * Project Title: Employee Performance Analysis – INX Future Inc.
# * Domain: HR Analytics
# * Problem Type: Supervised Learning – Multiclass Classification
#
# 1. Project Summary
# * The objective of this project was to analyze employee performance data of INX Future Inc. and identify the key factors affecting employee performance.
# * The project also aimed to build a robust machine learning model capable of predicting employee performance ratings to support management decision-making and future hiring strategies.
# * The dataset consisted of employee demographic details, job-related attributes, satisfaction metrics, experience-based variables, and performance ratings.
#
# 2. Data Understanding & EDA Summary
# * The dataset contained 28 features, including numerical, ordinal, and categorical variables.
# * No critical missing values were found.
# * The target variable PerformanceRating showed slight class imbalance, which was handled using SMOTE.
# * Exploratory Data Analysis revealed that:
#  Job satisfaction, environment satisfaction, experience, and salary-related features significantly influence performance.
# * Department-wise and role-wise performance variation exists.
# * Outliers were present mainly in income and experience variables, representing valid senior employee cases and were therefore retained.
#
# 3. Feature Engineering & Preprocessing
# * Irrelevant identifiers were removed.
# * Categorical variables (Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, OverTime, Attrition) were * encoded using One-Hot Encoding.
# * Ordinal variables were preserved as numeric values.
# * Feature scaling was applied where required.
# * The target variable was label-encoded for compatibility with all models.
# * Class imbalance was addressed using SMOTE on the training data.
# * Highly correlated features (correlation > 0.9) were identified to reduce multicollinearity.

# %% [markdown]
# #### Business Insights & Recommendations
#
# * Based on the analysis, the following recommendations are proposed:
# Improve Job & Environment Satisfaction
# * Employees with higher satisfaction scores consistently showed better performance.
# * Focus on Experience-Based Growth
# * Employees with moderate to high experience performed better—structured career progression plans are recommended.
# * Targeted Training Programs
# * Employees with fewer training sessions showed lower performance; regular training can improve productivity.
# * Department-Specific Interventions
# * Departments with lower performance should receive focused managerial and policy attention.
# * Data-Driven Hiring Strategy
# * The trained model can be used during recruitment to predict future employee performance.

# %%
results = {
    "Logistic Regression": {
        "Accuracy": 0.7958333333333333,
        "F1 Score": 0.7967990911343131
    },
    "SVM": {
        "Accuracy": 0.7666666666666667,
        "F1 Score": 0.7270846360499318
    },
    "Decision Tree": {
        "Accuracy": 0.875,
        "F1 Score": 0.8751541697296414
    },
    "Bagging": {
        "Accuracy": 0.9166666666666666,
        "F1 Score": 0.9155645969435933
    },
    "Random Forest": {
        "Accuracy": 0.9125,
        "F1 Score": 0.9111408450704225
    },
    "XGBoost": {
        "Accuracy": 0.9291666666666667,
        "F1 Score": 0.9281073446327684
    },
    "ANN": {
        "Accuracy": 0.7625,
        "F1 Score": 0.7634854768465839
    }
}

results_df = pd.DataFrame(results).T
results_df
# Out:
#                      Accuracy  F1 Score
# Logistic Regression  0.795833  0.796799
# SVM                  0.766667  0.727085
# Decision Tree        0.875000  0.875154
# Bagging              0.916667  0.915565
# Random Forest        0.912500  0.911141
# XGBoost              0.929167  0.928107
# ANN                  0.762500  0.763485

# %% [markdown]
# ### **Final Conclusion**
#
# * This project successfully demonstrated how data science and machine learning can be applied in the HR analytics domain to solve real-world business problems. By analyzing employee data and building predictive models, the organization can make objective, fair, and data-driven decisions without negatively impacting employee morale.
#
# * The XGBoost model provides a reliable solution for predicting employee performance and can be effectively integrated into INX Future Inc.’s talent management and hiring process.
